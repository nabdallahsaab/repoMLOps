# %%
import os
# Crédentials d'accès à AWS
os.environ['AWS_ACCESS_KEY_ID'] = "AKIA3R62MVALHESATEYJ"
os.environ['AWS_SECRET_ACCESS_KEY'] = "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"
os.environ['ARTIFACT_STORE_URI'] = "s3://isen-mlflow/models/"
os.environ['BACKEND_STORE_URI'] = "postgresql://mqnvdkpvcofzld:91fb99bacc7e38d371cd7e96e3b5b15967ce099bfc393b3ec1c3dd1502069cbf@ec2-54-73-103-21.eu-west-1.compute.amazonaws.com:5432/d1dcrr60p484dk"

# %%
import pandas as pd
# Import dataset
df = pd.read_csv("train.csv", sep=';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
# Features selection
df = df[['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'y']]
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#        campaign  pdays  previous poutcome    y
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# All dictioanry
all_dict = {}
le.fit_transform(df['job'])
all_dict['job'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['job'] = le.fit_transform(df['job'])


le.fit_transform(df['marital'])
all_dict['marital'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['marital'] = le.fit_transform(df['marital'])

le.fit_transform(df['education'])
all_dict['education'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['education'] = le.fit_transform(df['education'])

le.fit_transform(df['default'])
all_dict['default'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['default'] = le.fit_transform(df['default'])

le.fit_transform(df['housing'])
all_dict['housing'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['housing'] = le.fit_transform(df['housing'])

le.fit_transform(df['loan'])
all_dict['loan'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['loan'] = le.fit_transform(df['loan'])

le.fit_transform(df['poutcome'])
all_dict['poutcome'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['poutcome'] = le.fit_transform(df['poutcome'])

le.fit_transform(df['y'])
all_dict['y'] = dict(zip(le.classes_, le.transform(le.classes_)))
df['y'] = le.fit_transform(df['y'])

X=df[['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome']]
y=df['y']
# Out:
# C:\Users\ISEN\AppData\Local\Temp\ipykernel_27536\2382357728.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job'] = le.fit_transform(df['job'])
# C:\Users\ISEN\AppData\Local\Temp\ipykernel_27536\2382357728.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marital'] = le.fit_transform(df['marital'])
# C:\Users\ISEN\AppData\Local\Temp\ipykernel_27536\2382357728.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.model_selection import train_test_split



# Train / test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2)

# %%
import numpy as np
import json

# Convert numpy.int64 to int for all values in the dictionary
all_dict = {key: {sub_key: int(value) for sub_key, value in sub_dict.items()} for key, sub_dict in all_dict.items()}

# Save all dict in json
with open('all_dict.json', 'w') as fp:json.dump(all_dict, fp)
all_dict
# Out:
# {'job': {'admin.': 0,
#   'blue-collar': 1,
#   'entrepreneur': 2,
#   'housemaid': 3,
#   'management': 4,
#   'retired': 5,
#   'self-employed': 6,
#   'services': 7,
#   'student': 8,
#   'technician': 9,
#   'unemployed': 10,
#   'unknown': 11},
#  'marital': {'divorced': 0, 'married': 1, 'single': 2},
#  'education': {'primary': 0, 'secondary': 1, 'tertiary': 2, 'unknown': 3},
#  'default': {'no': 0, 'yes': 1},
#  'housing': {'no': 0, 'yes': 1},
#  'loan': {'no': 0, 'yes': 1},
#  'poutcome': {'failure': 0, 'other': 1, 'success': 2, 'unknown': 3},
#  'y': {'no': 0, 'yes': 1}}

# %%
import os
os.environ
# Out:
# environ{'ACSETUPSVCPORT': '23210',
#         'ACSVCPORT': '17532',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\ISEN\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_16012_OSCBSZMMVHHNJXAG',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'PC-NABDALLAH',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_DEFAULT_ENV': 'venv_fastapi',
#         'CONDA_EXE': 'C:\\Users\\ISEN\\anaconda3\\condabin\\..\\Scripts\\conda.exe',
#         'CONDA_EXES': '"C:\\Users\\ISEN\\anaconda3\\condabin\\..\\Scripts\\conda.exe"  ',
#         'CONDA_PREFIX': 'C:\\Users\\ISEN\\anaconda3\\envs\\venv_fastapi',
#         'CONDA_PROMPT_MODIFIER': '(venv_fastapi) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\ISEN\\anaconda3\\python.exe',
# ...

# %%
import mlflow
from mlflow.models import infer_signature
import mlflow
import os

os.environ['AWS_ACCESS_KEY_ID'] = "AKIA3R62MVALHESATEYJ"
os.environ['AWS_SECRET_ACCESS_KEY'] = "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"
os.environ['ARTIFACT_STORE_URI'] = "s3://isen-mlflow/models/"

# Connexion à MLflow
# mlflow.set_tracking_uri("http://127.0.0.1:5000/")
mlflow.set_tracking_uri("https://isen-mlflow-nadine-21ef323e2826.herokuapp.com/")
# Configuration de l'autolog
mlflow.sklearn.autolog()
# Out:
# 2024/02/02 09:51:58 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.

# %%
from sklearn.preprocessing import  StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# Infer signature : obtention des informations sur les colonnes en entrée
signature = infer_signature(X_train, y_train)

# Configuration d'une expérience (création si elle n'existe pas)
mlflow.set_experiment("ISEN - Nadine - Experience 2")
mlflow.start_run(run_name="Test - Run")
    # Pipeline d'entraînement
model = Pipeline(steps=[
        ("standard_scaler", StandardScaler()),
        ("Classifier",RandomForestClassifier())
])

    # Entraînement du modèle
model.fit(X_train, y_train)

    # Log des métriques
mlflow.log_metric("train_score", model.score(X_train, y_train))


mlflow.sklearn.log_model(model,                                             # Sauvegarde du modèle
                            "model Bank 22",                                   # Nom du modèle
                            signature=signature,                                # Informations sur les colonnes en entrée
                            input_example=X_train.head(1),                      # Exemple d'entrée
                            registered_model_name="Bank"               # Nom du modèle enregistré
                            )


# Print Scores
print(f"Train score: {model.score(X_train, y_train)}")
print(f"Test score: {model.score(X_test, y_test)}")
mlflow.end_run()
# Out:
# c:\Users\ISEN\anaconda3\envs\venv_fastapi\lib\site-packages\mlflow\models\signature.py:212: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   inputs = _infer_schema(model_input) if model_input is not None else None
# ...

# %%
import mlflow
logged_model = 'runs:/6f5d7ef26b6c486ba19f859d6720a6cd/model Bank 22'
import os
# # Crédentials d'accès à AWS
os.environ['AWS_ACCESS_KEY_ID'] = "AKIA3R62MVALHESATEYJ"
os.environ['AWS_SECRET_ACCESS_KEY'] = "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"
os.environ['ARTIFACT_STORE_URI'] = "s3://isen-mlflow/models/"
os.environ['BACKEND_STORE_URI'] = "postgresql://mqnvdkpvcofzld:91fb99bacc7e38d371cd7e96e3b5b15967ce099bfc393b3ec1c3dd1502069cbf@ec2-54-73-103-21.eu-west-1.compute.amazonaws.com:5432/d1dcrr60p484dk"
mlflow.set_tracking_uri("https://isen-mlflow-nadine-21ef323e2826.herokuapp.com/")
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[13], line 11
#       8 os.environ['BACKEND_STORE_URI'] = "postgresql://mqnvdkpvcofzld:91fb99bacc7e38d371cd7e96e3b5b15967ce099bfc393b3ec1c3dd1502069cbf@ec2-54-73-103-21.eu-west-1.compute.amazonaws.com:5432/d1dcrr60p484dk"
#      10 # Load model as a PyFuncModel.
# ---> 11 loaded_model = mlflow.pyfunc.load_model(logged_model)
#
# File c:\Users\ISEN\anaconda3\envs\venv_fastapi\lib\site-packages\mlflow\pyfunc\__init__.py:617, in load_model(model_uri, suppress_warnings, dst_path)
#     589 def load_model(
#     590     model_uri: str,
#     591     suppress_warnings: bool = False,
#     592     dst_path: str = None,
#     593 ) -> PyFuncModel:
#     594     """
#     595     Load a model stored in Python function format.
#     596
#    (...)
#     615                      path will be created.
#     616     """
# ...

# %%
res=loaded_model.predict([X_test[0,:]])
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 res=loaded_model.predict([X_test[0,:]])
#       2 res
#
# NameError: name 'loaded_model' is not defined
